# %%
import pandas as pd
import nltk 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('all')
import string
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
from nltk.stem import PorterStemmer
import matplotlib.image as mpimg
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\dpino\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# Este texto, "Barcelona da forma al futuro del urbanismo", habla de como en Barcelona, se esta creando un modelo el Digital Twin, que es una replica virtual de todos los sistemas que conforman la ciudad, para comprender como funciona la ciudad y dar soluciones a futuro mas eficaces y solidas. esto permitira hacer simulaciones de situaciones o predecir como los cambios de un sistema afectan a la ciudad. ejemplo de la imprementación de estos modelos, son por ejemplo los implementados en rotterdam.
#
# La idea de este proyecto para Barcelona se centra en la planificacion urbana de la ciudad, la idea es poder incorporar nuevos sistemas que hagan un modelo mas robusto y que se puedan evaluar las interacciones entre si para poder entender y planear acciones que permitan que la ciudad funcione de manera eficiente.

# %%
BCN = '''Barcelona shapes the future of city Planning
The city of Barcelona is cooking up something truly special: a Local Digital Twin (LTD) that resembles a delicious lasagna. Just like how this dish has layers of pasta, cheese, and sauce, the Digital Twin aims to include different layers of systems to create a virtual replica of the city.
Much like the first step of including a solid base when cooking lasagna, Barcelona has replaced the pasta with a virtual representation of the city’s physical reality. “The bottom layer is made up of the map, images of the city, satellite photographs, the street furniture, all the trees, the buildings, the people. It represents the physical world,” explains Jordi Cirera, Director of the Knowledge Society Office of the Barcelona City Council.
But that is not enough. To truly grasp how a city works, you need to throw more ingredients into the mix. This is why the City Council of Barcelona, in collaboration with the Barcelona Supercomputing Centre and the Barcelona Regional agency, has started a new and much more ambitious project. They aim to add new layers to the lasagna, namely the different systems that affect the functioning and behaviour of cities.
“Air pollution and noise monitoring, how goods are distributed throughout the city, traffic management and monitoring, or how people move around, are some of the systems that compose a city model”, notes Cirera. “We want to incorporate these systems and the laws that govern them into the Digital Twin.”
With this comprehensive view of Barcelona, the Local Digital Twin would allow decision makers to run simulations and predict how changes in one system will affect the city. According to Cirera, this technology “will allow the City Council to design, orient and prepare for the Barcelona of the future.”
Digital Twins and the urban planning revolution
Digital Twins are much more than a digital replica of physical systems, people, and environments. They are different from other data analysis and visualisation approaches because they can integrate data from various sources in real time and assess future scenarios through advanced simulations. When applied in urban contexts, DTs can revolutionise how cities approach their management, monitoring, and future planning.
Digital Twins have proven to have many practical applications for cities. Rotterdam, for instance, is building a 3-D city operations platform that allows for the disclosure and visualisation of real-time energy usage data from individual buildings and the entire area.
Flanders, as part of the DUET Digital Twins project, is developing a traffic model that estimates the expected traffic volume in surrounding streets when one or more streets are closed.
The interaction between the traffic model and air quality model allows the simulation of the impact of traffic measures on mobility and the environment. The city of Utrecht is also using a Local Digital Twin, developing an open-source solution that can be adapted to various domains, such as mobility and healthy urban living.
Shaping the city of proximity
Barcelona has developed a ground-breaking Digital Twin platform that serves as a proof of concept and starting point for the city’s ambitious urban planning project. The platform provides a tool to assess whether the city complies with the provision of services or facilities of the city of proximity. The concept is based on the ‘15-minute model’. This term, coined by Paris-based researcher Carlos Moreno, is based on the idea that all essential human needs should be within a 15-minute reach by foot or bike. This means that housing, work, food, health, education, and culture and leisure should be easily accessible to everyone.
Barcelona’s platform analyses the accessibility of public facilities, such as metro stations, hospitals, libraries, or water fountains, among many others. “The platform addresses the six social functions of the 15-minute model, and we could include any data set that the city council has available”, says Cirera. The Digital Twin allows policy makers to evaluate the impact of new construction projects on the city’s infrastructure and assess the accessibility of these facilities to the public. “By including data from the municipal register, for example, we could not only identify areas not covered by the 15-minute model, but also how many people are being left out,” he remarks.
The platform can be replicated in other cities for their own urban planning needs. “Adapting it to other cities and regions should not be too complicated,” acknowledges Jordi Ortuño, Innovation Manager at the Knowledge Society Office of the Barcelona City Council, “it is a matter of changing the map and incorporating the city’s data.” Along with the 15-minute city model, it has many other potential uses. City Councils can include any data set they have available, depending on their intended use of the platform. For instance, they can use it to monitor the location of social and community centres, electric car charging stations, or bicycle racks.
Building a city-wide modelling programme
The Digital Twin of Barcelona is set to become even more complex as it moves into its next phase. Just like adding layers to a lasagna, the project aims to add new levels of complexity that incorporate the many different systems that intervene in city planning.
“During the first phase, known as the 15-minute platform, we have created a digital copy of the city of Barcelona, representing a highly detailed but static photograph”, mentions Ortuño. The platform is the result of the first phase of an ambitious project in which the City Council has worked closely with researchers from the Barcelona Supercomputing centre.
Now, they are launching a second stage, aimed at creating a city-wide modelling programme. The model aims to reproduce how different physical, social, and digital systems impact each other and the city.
Introducing a small change in the choice of ingredients for the lasagna -for example, sugar instead of salt – results in a quite different dish. The same is true for city systems. When this phase of the project is completed, the Digital Twin would be able to assess, for example, how changes on citizens’ employment patterns affect the level of traffic and, therefore, air pollution levels, or how closing a street can affect noise levels in neighbouring areas.
By adding these systems and the rules that govern them, the model will be able to provide city planners with a deeper understanding of how the different systems interact with each other, enabling them to make more informed decisions that will have a positive impact on the city.
However, such a complex project will require a significant amount of time to complete. The municipalities of Bologna and Barcelona, together with the Barcelona Supercomputing Center (BSC-CNS) and the CINECA Consortium of Universities, are defining the milestones to be completed during the development of this initiative. The current objective is to define concretely what collaborations and joint projects will be developed during this phase within a European framework.
One of the biggest challenges they will face is understanding the rules that govern these systems, as they are often incredibly complex and not well understood. “We aim to have a record of data for systems whose laws are unclear. The goal is to use an artificial intelligence system to infer or approximate the outcomes,” discloses Cirera.
A shared culture on Digital Twins
Although the concept of the Local Digital Twin is something new, the idea behind this technology has been around for a long time. “Ultimately, such tools are not about inventing anything new,” points Cirera. “It is about answering four fundamental questions that we have been asking ourselves for a long time: What has happened, what is happening now, what will happen in the future, and what if something were to change?”
The development of the Barcelona LDT highlights the critical role that collaboration between cities and organisations plays in achieving ambitious goals. The project would not have been possible without the agreement between Barcelona and Bologna, who teamed up with two of Europe’s most powerful supercomputers: the Barcelona Supercomputing Center (BSC-CNS) and the CINECA Consortium of Universities, which includes the University of Bologna. By combining resources and expertise, these partners were able to push the boundaries of what was possible. This serves as a reminder that collaboration is essential to developing large-scale projects and achieving significant breakthroughs.
As more and more EU cities begin to adopt Local Digital Twins (LDTs), the potential benefits of this cutting-edge technology are becoming increasingly clear. To ensure that as many cities and communities as possible can take advantage of LDTs, and to foster a fair and innovative European digital twin market, Ortuño defends that “ensuring spaces for working together, sharing knowledge and best practices is essential.”
In this sense, the Living-in.eu community has set up a specific forum on Local Digital Twins. Thanks to the collaboration between city, regional and national experts, the Living-in.EU comunity aims to identify existing use cases and potential interest from different groups across the EU. The European Commission has launched funding calls to develop an EU LDT Toolbox, which will provide cities with re-usable tools, reference architectures, open standards, and technical specifications. Furthermore, the Eurocities Task Force on Digital Twins worked last year to promote a culture of Digital Twins, in which smart cities can share experiences, knowledge, initiatives, best practices and harmonise strategies. All these measures aim to enable interoperability, facilitate the creation of a network of LDTs, and spur innovation among European cities and communities.'''
print(BCN)
# Out:
# Barcelona shapes the future of city Planning
# The city of Barcelona is cooking up something truly special: a Local Digital Twin (LTD) that resembles a delicious lasagna. Just like how this dish has layers of pasta, cheese, and sauce, the Digital Twin aims to include different layers of systems to create a virtual replica of the city.
# Much like the first step of including a solid base when cooking lasagna, Barcelona has replaced the pasta with a virtual representation of the city’s physical reality. “The bottom layer is made up of the map, images of the city, satellite photographs, the street furniture, all the trees, the buildings, the people. It represents the physical world,” explains Jordi Cirera, Director of the Knowledge Society Office of the Barcelona City Council.
# But that is not enough. To truly grasp how a city works, you need to throw more ingredients into the mix. This is why the City Council of Barcelona, in collaboration with the Barcelona Supercomputing Centre and the Barcelona Regional agency, has started a new and much more ambitious project. They aim to add new layers to the lasagna, namely the different systems that affect the functioning and behaviour of cities.
# “Air pollution and noise monitoring, how goods are distributed throughout the city, traffic management and monitoring, or how people move around, are some of the systems that compose a city model”, notes Cirera. “We want to incorporate these systems and the laws that govern them into the Digital Twin.”
# With this comprehensive view of Barcelona, the Local Digital Twin would allow decision makers to run simulations and predict how changes in one system will affect the city. According to Cirera, this technology “will allow the City Council to design, orient and prepare for the Barcelona of the future.”
# Digital Twins and the urban planning revolution
# Digital Twins are much more than a digital replica of physical systems, people, and environments. They are different from other data analysis and visualisation approaches because they can integrate data from various sources in real time and assess future scenarios through advanced simulations. When applied in urban contexts, DTs can revolutionise how cities approach their management, monitoring, and future planning.
# Digital Twins have proven to have many practical applications for cities. Rotterdam, for instance, is building a 3-D city operations platform that allows for the disclosure and visualisation of real-time energy usage data from individual buildings and the entire area.
# Flanders, as part of the DUET Digital Twins project, is developing a traffic model that estimates the expected traffic volume in surrounding streets when one or more streets are closed.
# The interaction between the traffic model and air quality model allows the simulation of the impact of traffic measures on mobility and the environment. The city of Utrecht is also using a Local Digital Twin, developing an open-source solution that can be adapted to various domains, such as mobility and healthy urban living.
# Shaping the city of proximity
# Barcelona has developed a ground-breaking Digital Twin platform that serves as a proof of concept and starting point for the city’s ambitious urban planning project. The platform provides a tool to assess whether the city complies with the provision of services or facilities of the city of proximity. The concept is based on the ‘15-minute model’. This term, coined by Paris-based researcher Carlos Moreno, is based on the idea that all essential human needs should be within a 15-minute reach by foot or bike. This means that housing, work, food, health, education, and culture and leisure should be easily accessible to everyone.
# Barcelona’s platform analyses the accessibility of public facilities, such as metro stations, hospitals, libraries, or water fountains, among many others. “The platform addresses the six social functions of the 15-minute model, and we could include any data set that the city council has available”, says Cirera. The Digital Twin allows policy makers to evaluate the impact of new construction projects on the city’s infrastructure and assess the accessibility of these facilities to the public. “By including data from the municipal register, for example, we could not only identify areas not covered by the 15-minute model, but also how many people are being left out,” he remarks.
# The platform can be replicated in other cities for their own urban planning needs. “Adapting it to other cities and regions should not be too complicated,” acknowledges Jordi Ortuño, Innovation Manager at the Knowledge Society Office of the Barcelona City Council, “it is a matter of changing the map and incorporating the city’s data.” Along with the 15-minute city model, it has many other potential uses. City Councils can include any data set they have available, depending on their intended use of the platform. For instance, they can use it to monitor the location of social and community centres, electric car charging stations, or bicycle racks.
# Building a city-wide modelling programme
# The Digital Twin of Barcelona is set to become even more complex as it moves into its next phase. Just like adding layers to a lasagna, the project aims to add new levels of complexity that incorporate the many different systems that intervene in city planning.
# “During the first phase, known as the 15-minute platform, we have created a digital copy of the city of Barcelona, representing a highly detailed but static photograph”, mentions Ortuño. The platform is the result of the first phase of an ambitious project in which the City Council has worked closely with researchers from the Barcelona Supercomputing centre.
# Now, they are launching a second stage, aimed at creating a city-wide modelling programme. The model aims to reproduce how different physical, social, and digital systems impact each other and the city.
# Introducing a small change in the choice of ingredients for the lasagna -for example, sugar instead of salt – results in a quite different dish. The same is true for city systems. When this phase of the project is completed, the Digital Twin would be able to assess, for example, how changes on citizens’ employment patterns affect the level of traffic and, therefore, air pollution levels, or how closing a street can affect noise levels in neighbouring areas.
# By adding these systems and the rules that govern them, the model will be able to provide city planners with a deeper understanding of how the different systems interact with each other, enabling them to make more informed decisions that will have a positive impact on the city.
# However, such a complex project will require a significant amount of time to complete. The municipalities of Bologna and Barcelona, together with the Barcelona Supercomputing Center (BSC-CNS) and the CINECA Consortium of Universities, are defining the milestones to be completed during the development of this initiative. The current objective is to define concretely what collaborations and joint projects will be developed during this phase within a European framework.
# One of the biggest challenges they will face is understanding the rules that govern these systems, as they are often incredibly complex and not well understood. “We aim to have a record of data for systems whose laws are unclear. The goal is to use an artificial intelligence system to infer or approximate the outcomes,” discloses Cirera.
# A shared culture on Digital Twins
# Although the concept of the Local Digital Twin is something new, the idea behind this technology has been around for a long time. “Ultimately, such tools are not about inventing anything new,” points Cirera. “It is about answering four fundamental questions that we have been asking ourselves for a long time: What has happened, what is happening now, what will happen in the future, and what if something were to change?”
# The development of the Barcelona LDT highlights the critical role that collaboration between cities and organisations plays in achieving ambitious goals. The project would not have been possible without the agreement between Barcelona and Bologna, who teamed up with two of Europe’s most powerful supercomputers: the Barcelona Supercomputing Center (BSC-CNS) and the CINECA Consortium of Universities, which includes the University of Bologna. By combining resources and expertise, these partners were able to push the boundaries of what was possible. This serves as a reminder that collaboration is essential to developing large-scale projects and achieving significant breakthroughs.
# As more and more EU cities begin to adopt Local Digital Twins (LDTs), the potential benefits of this cutting-edge technology are becoming increasingly clear. To ensure that as many cities and communities as possible can take advantage of LDTs, and to foster a fair and innovative European digital twin market, Ortuño defends that “ensuring spaces for working together, sharing knowledge and best practices is essential.”
# In this sense, the Living-in.eu community has set up a specific forum on Local Digital Twins. Thanks to the collaboration between city, regional and national experts, the Living-in.EU comunity aims to identify existing use cases and potential interest from different groups across the EU. The European Commission has launched funding calls to develop an EU LDT Toolbox, which will provide cities with re-usable tools, reference architectures, open standards, and technical specifications. Furthermore, the Eurocities Task Force on Digital Twins worked last year to promote a culture of Digital Twins, in which smart cities can share experiences, knowledge, initiatives, best practices and harmonise strategies. All these measures aim to enable interoperability, facilitate the creation of a network of LDTs, and spur innovation among European cities and communities.

# %% [markdown]
# ##### Ejercicio 1
# Coge un texto en inglés que quieras, y calcula la frecuencia de sus palabras.

# %% [markdown]
# ##### Limpieza de texto y tokenización.

# %% [markdown]
# Para calcular la frecuencia de las palabras en el texto, primero debemos limpiar el texto, dividiendo el texto en palabras, eliminando signos de puntuacion y convirtiendo todas las palabras a minusculas para asegurar que cuente correctamente la frecuencia. para esto usamos la funcion word_tokenize, que nos limpia el texto de forma predeterminada.

# %%
# TOKENIZACIÓN DEL TEXTO EN PALABRAS. (divide el texto en palabras)
tokens = word_tokenize(BCN.lower())
print(tokens)
print(f'\nNombre de paraules al text: {len(tokens)}')
# Out:
# ['barcelona', 'shapes', 'the', 'future', 'of', 'city', 'planning', 'the', 'city', 'of', 'barcelona', 'is', 'cooking', 'up', 'something', 'truly', 'special', ':', 'a', 'local', 'digital', 'twin', '(', 'ltd', ')', 'that', 'resembles', 'a', 'delicious', 'lasagna', '.', 'just', 'like', 'how', 'this', 'dish', 'has', 'layers', 'of', 'pasta', ',', 'cheese', ',', 'and', 'sauce', ',', 'the', 'digital', 'twin', 'aims', 'to', 'include', 'different', 'layers', 'of', 'systems', 'to', 'create', 'a', 'virtual', 'replica', 'of', 'the', 'city', '.', 'much', 'like', 'the', 'first', 'step', 'of', 'including', 'a', 'solid', 'base', 'when', 'cooking', 'lasagna', ',', 'barcelona', 'has', 'replaced', 'the', 'pasta', 'with', 'a', 'virtual', 'representation', 'of', 'the', 'city', '’', 's', 'physical', 'reality', '.', '“', 'the', 'bottom', 'layer', 'is', 'made', 'up', 'of', 'the', 'map', ',', 'images', 'of', 'the', 'city', ',', 'satellite', 'photographs', ',', 'the', 'street', 'furniture', ',', 'all', 'the', 'trees', ',', 'the', 'buildings', ',', 'the', 'people', '.', 'it', 'represents', 'the', 'physical', 'world', ',', '”', 'explains', 'jordi', 'cirera', ',', 'director', 'of', 'the', 'knowledge', 'society', 'office', 'of', 'the', 'barcelona', 'city', 'council', '.', 'but', 'that', 'is', 'not', 'enough', '.', 'to', 'truly', 'grasp', 'how', 'a', 'city', 'works', ',', 'you', 'need', 'to', 'throw', 'more', 'ingredients', 'into', 'the', 'mix', '.', 'this', 'is', 'why', 'the', 'city', 'council', 'of', 'barcelona', ',', 'in', 'collaboration', 'with', 'the', 'barcelona', 'supercomputing', 'centre', 'and', 'the', 'barcelona', 'regional', 'agency', ',', 'has', 'started', 'a', 'new', 'and', 'much', 'more', 'ambitious', 'project', '.', 'they', 'aim', 'to', 'add', 'new', 'layers', 'to', 'the', 'lasagna', ',', 'namely', 'the', 'different', 'systems', 'that', 'affect', 'the', 'functioning', 'and', 'behaviour', 'of', 'cities', '.', '“', 'air', 'pollution', 'and', 'noise', 'monitoring', ',', 'how', 'goods', 'are', 'distributed', 'throughout', 'the', 'city', ',', 'traffic', 'management', 'and', 'monitoring', ',', 'or', 'how', 'people', 'move', 'around', ',', 'are', 'some', 'of', 'the', 'systems', 'that', 'compose', 'a', 'city', 'model', '”', ',', 'notes', 'cirera', '.', '“', 'we', 'want', 'to', 'incorporate', 'these', 'systems', 'and', 'the', 'laws', 'that', 'govern', 'them', 'into', 'the', 'digital', 'twin.', '”', 'with', 'this', 'comprehensive', 'view', 'of', 'barcelona', ',', 'the', 'local', 'digital', 'twin', 'would', 'allow', 'decision', 'makers', 'to', 'run', 'simulations', 'and', 'predict', 'how', 'changes', 'in', 'one', 'system', 'will', 'affect', 'the', 'city', '.', 'according', 'to', 'cirera', ',', 'this', 'technology', '“', 'will', 'allow', 'the', 'city', 'council', 'to', 'design', ',', 'orient', 'and', 'prepare', 'for', 'the', 'barcelona', 'of', 'the', 'future.', '”', 'digital', 'twins', 'and', 'the', 'urban', 'planning', 'revolution', 'digital', 'twins', 'are', 'much', 'more', 'than', 'a', 'digital', 'replica', 'of', 'physical', 'systems', ',', 'people', ',', 'and', 'environments', '.', 'they', 'are', 'different', 'from', 'other', 'data', 'analysis', 'and', 'visualisation', 'approaches', 'because', 'they', 'can', 'integrate', 'data', 'from', 'various', 'sources', 'in', 'real', 'time', 'and', 'assess', 'future', 'scenarios', 'through', 'advanced', 'simulations', '.', 'when', 'applied', 'in', 'urban', 'contexts', ',', 'dts', 'can', 'revolutionise', 'how', 'cities', 'approach', 'their', 'management', ',', 'monitoring', ',', 'and', 'future', 'planning', '.', 'digital', 'twins', 'have', 'proven', 'to', 'have', 'many', 'practical', 'applications', 'for', 'cities', '.', 'rotterdam', ',', 'for', 'instance', ',', 'is', 'building', 'a', '3-d', 'city', 'operations', 'platform', 'that', 'allows', 'for', 'the', 'disclosure', 'and', 'visualisation', 'of', 'real-time', 'energy', 'usage', 'data', 'from', 'individual', 'buildings', 'and', 'the', 'entire', 'area', '.', 'fla ...
#
# Nombre de paraules al text: 1785

# %%
tokens_filtrados = [word for word in tokens if word.isalpha()] # Eliminamos los signos de puntuación, para luego contabilizar.
print(tokens_filtrados)
# Out:
# ['barcelona', 'shapes', 'the', 'future', 'of', 'city', 'planning', 'the', 'city', 'of', 'barcelona', 'is', 'cooking', 'up', 'something', 'truly', 'special', 'a', 'local', 'digital', 'twin', 'ltd', 'that', 'resembles', 'a', 'delicious', 'lasagna', 'just', 'like', 'how', 'this', 'dish', 'has', 'layers', 'of', 'pasta', 'cheese', 'and', 'sauce', 'the', 'digital', 'twin', 'aims', 'to', 'include', 'different', 'layers', 'of', 'systems', 'to', 'create', 'a', 'virtual', 'replica', 'of', 'the', 'city', 'much', 'like', 'the', 'first', 'step', 'of', 'including', 'a', 'solid', 'base', 'when', 'cooking', 'lasagna', 'barcelona', 'has', 'replaced', 'the', 'pasta', 'with', 'a', 'virtual', 'representation', 'of', 'the', 'city', 's', 'physical', 'reality', 'the', 'bottom', 'layer', 'is', 'made', 'up', 'of', 'the', 'map', 'images', 'of', 'the', 'city', 'satellite', 'photographs', 'the', 'street', 'furniture', 'all', 'the', 'trees', 'the', 'buildings', 'the', 'people', 'it', 'represents', 'the', 'physical', 'world', 'explains', 'jordi', 'cirera', 'director', 'of', 'the', 'knowledge', 'society', 'office', 'of', 'the', 'barcelona', 'city', 'council', 'but', 'that', 'is', 'not', 'enough', 'to', 'truly', 'grasp', 'how', 'a', 'city', 'works', 'you', 'need', 'to', 'throw', 'more', 'ingredients', 'into', 'the', 'mix', 'this', 'is', 'why', 'the', 'city', 'council', 'of', 'barcelona', 'in', 'collaboration', 'with', 'the', 'barcelona', 'supercomputing', 'centre', 'and', 'the', 'barcelona', 'regional', 'agency', 'has', 'started', 'a', 'new', 'and', 'much', 'more', 'ambitious', 'project', 'they', 'aim', 'to', 'add', 'new', 'layers', 'to', 'the', 'lasagna', 'namely', 'the', 'different', 'systems', 'that', 'affect', 'the', 'functioning', 'and', 'behaviour', 'of', 'cities', 'air', 'pollution', 'and', 'noise', 'monitoring', 'how', 'goods', 'are', 'distributed', 'throughout', 'the', 'city', 'traffic', 'management', 'and', 'monitoring', 'or', 'how', 'people', 'move', 'around', 'are', 'some', 'of', 'the', 'systems', 'that', 'compose', 'a', 'city', 'model', 'notes', 'cirera', 'we', 'want', 'to', 'incorporate', 'these', 'systems', 'and', 'the', 'laws', 'that', 'govern', 'them', 'into', 'the', 'digital', 'with', 'this', 'comprehensive', 'view', 'of', 'barcelona', 'the', 'local', 'digital', 'twin', 'would', 'allow', 'decision', 'makers', 'to', 'run', 'simulations', 'and', 'predict', 'how', 'changes', 'in', 'one', 'system', 'will', 'affect', 'the', 'city', 'according', 'to', 'cirera', 'this', 'technology', 'will', 'allow', 'the', 'city', 'council', 'to', 'design', 'orient', 'and', 'prepare', 'for', 'the', 'barcelona', 'of', 'the', 'digital', 'twins', 'and', 'the', 'urban', 'planning', 'revolution', 'digital', 'twins', 'are', 'much', 'more', 'than', 'a', 'digital', 'replica', 'of', 'physical', 'systems', 'people', 'and', 'environments', 'they', 'are', 'different', 'from', 'other', 'data', 'analysis', 'and', 'visualisation', 'approaches', 'because', 'they', 'can', 'integrate', 'data', 'from', 'various', 'sources', 'in', 'real', 'time', 'and', 'assess', 'future', 'scenarios', 'through', 'advanced', 'simulations', 'when', 'applied', 'in', 'urban', 'contexts', 'dts', 'can', 'revolutionise', 'how', 'cities', 'approach', 'their', 'management', 'monitoring', 'and', 'future', 'planning', 'digital', 'twins', 'have', 'proven', 'to', 'have', 'many', 'practical', 'applications', 'for', 'cities', 'rotterdam', 'for', 'instance', 'is', 'building', 'a', 'city', 'operations', 'platform', 'that', 'allows', 'for', 'the', 'disclosure', 'and', 'visualisation', 'of', 'energy', 'usage', 'data', 'from', 'individual', 'buildings', 'and', 'the', 'entire', 'area', 'flanders', 'as', 'part', 'of', 'the', 'duet', 'digital', 'twins', 'project', 'is', 'developing', 'a', 'traffic', 'model', 'that', 'estimates', 'the', 'expected', 'traffic', 'volume', 'in', 'surrounding', 'streets', 'when', 'one', 'or', 'more', 'streets', 'are', 'closed', 'the', 'interaction', 'between', 'the', 'traffic', 'model', 'and', ...

# %%
frecuencia_palabras = Counter(tokens_filtrados) #(contabiliza, cuantas veces se repite cada "palabra" de caracteres alfabeticos.)
print(frecuencia_palabras)
# Out:
# Counter({'the': 127, 'of': 63, 'and': 52, 'to': 42, 'a': 40, 'city': 32, 'digital': 23, 'is': 22, 'that': 22, 'barcelona': 20, 'in': 15, 'for': 15, 'this': 13, 'systems': 12, 'are': 12, 'how': 11, 'has': 11, 'with': 11, 'cities': 11, 'as': 11, 'twin': 10, 'model': 10, 'on': 10, 'will': 9, 'twins': 9, 'can': 9, 'platform': 9, 'be': 9, 'different': 8, 'more': 8, 'project': 8, 'they': 8, 'or': 8, 'have': 8, 'it': 7, 'not': 7, 'data': 7, 'planning': 6, 'local': 6, 's': 6, 'cirera': 6, 'council': 6, 'new': 6, 'traffic': 6, 'we': 6, 'these': 6, 'from': 6, 'other': 6, 'many': 6, 'by': 6, 'what': 6, 'lasagna': 5, 'urban': 5, 'phase': 5, 'future': 4, 'up': 4, 'layers': 4, 'aims': 4, 'when': 4, 'physical': 4, 'people': 4, 'knowledge': 4, 'collaboration': 4, 'supercomputing': 4, 'ambitious': 4, 'affect': 4, 'time': 4, 'assess': 4, 'between': 4, 'impact': 4, 'an': 4, 'such': 4, 'set': 4, 'use': 4, 'which': 4, 'european': 4, 'something': 3, 'like': 3, 'include': 3, 'much': 3, 'first': 3, 'all': 3, 'but': 3, 'into': 3, 'aim': 3, 'air': 3, 'monitoring': 3, 'govern': 3, 'them': 3, 'would': 3, 'one': 3, 'technology': 3, 'their': 3, 'allows': 3, 'developing': 3, 'concept': 3, 'facilities': 3, 'should': 3, 'culture': 3, 'social': 3, 'projects': 3, 'example': 3, 'ortuño': 3, 'potential': 3, 'complex': 3, 'levels': 3, 'during': 3, 'able': 3, 'bologna': 3, 'been': 3, 'possible': 3, 'eu': 3, 'ldts': 3, 'cooking': 2, 'truly': 2, 'just': 2, 'dish': 2, 'pasta': 2, 'virtual': 2, 'replica': 2, 'including': 2, 'map': 2, 'street': 2, 'buildings': 2, 'jordi': 2, 'society': 2, 'office': 2, 'ingredients': 2, 'centre': 2, 'regional': 2, 'add': 2, 'pollution': 2, 'noise': 2, 'management': 2, 'around': 2, 'incorporate': 2, 'laws': 2, 'allow': 2, 'makers': 2, 'simulations': 2, 'changes': 2, 'system': 2, 'visualisation': 2, 'various': 2, 'instance': 2, 'building': 2, 'streets': 2, 'measures': 2, 'mobility': 2, 'also': 2, 'proximity': 2, 'developed': 2, 'serves': 2, 'based': 2, 'idea': 2, 'essential': 2, 'needs': 2, 'within': 2, 'accessibility': 2, 'public': 2, 'stations': 2, 'among': 2, 'could': 2, 'any': 2, 'available': 2, 'identify': 2, 'areas': 2, 'innovation': 2, 'at': 2, 'community': 2, 'modelling': 2, 'programme': 2, 'adding': 2, 'worked': 2, 'now': 2, 'each': 2, 'change': 2, 'completed': 2, 'rules': 2, 'provide': 2, 'understanding': 2, 'significant': 2, 'together': 2, 'center': 2, 'cineca': 2, 'consortium': 2, 'universities': 2, 'development': 2, 'long': 2, 'tools': 2, 'about': 2, 'were': 2, 'ldt': 2, 'achieving': 2, 'communities': 2, 'best': 2, 'practices': 2, 'shapes': 1, 'special': 1, 'ltd': 1, 'resembles': 1, 'delicious': 1, 'cheese': 1, 'sauce': 1, 'create': 1, 'step': 1, 'solid': 1, 'base': 1, 'replaced': 1, 'representation': 1, 'reality': 1, 'bottom': 1, 'layer': 1, 'made': 1, 'images': 1, 'satellite': 1, 'photographs': 1, 'furniture': 1, 'trees': 1, 'represents': 1, 'world': 1, 'explains': 1, 'director': 1, 'enough': 1, 'grasp': 1, 'works': 1, 'you': 1, 'need': 1, 'throw': 1, 'mix': 1, 'why': 1, 'agency': 1, 'started': 1, 'namely': 1, 'functioning': 1, 'behaviour': 1, 'goods': 1, 'distributed': 1, 'throughout': 1, 'move': 1, 'some': 1, 'compose': 1, 'notes': 1, 'want': 1, 'comprehensive': 1, 'view': 1, 'decision': 1, 'run': 1, 'predict': 1, 'according': 1, 'design': 1, 'orient': 1, 'prepare': 1, 'revolution': 1, 'than': 1, 'environments': 1, 'analysis': 1, 'approaches': 1, 'because': 1, 'integrate': 1, 'sources': 1, 'real': 1, 'scenarios': 1, 'through': 1, 'advanced': 1, 'applied': 1, 'contexts': 1, 'dts': 1, 'revolutionise': 1, 'approach': 1, 'proven': 1, 'practical': 1, 'applications': 1, 'rotterdam': 1, 'operations': 1, 'disclosure': 1, 'energy': 1, 'usage': 1, 'individual': 1, 'entire': 1, 'area': 1, 'flanders': 1, 'part': 1, 'duet': 1, 'estimates': 1, 'expected': 1, 'volume': 1, 'surrounding': 1, 'closed': 1, 'interaction': 1, 'quality': 1, 'simulation': 1, 'environment': 1, 'utrecht': 1, 'using': 1, 'solution': 1, 'adapted': 1, 'domains': 1, ' ...

# %%
top_15_palabras = frecuencia_palabras.most_common(15)
top_15_palabras
# Out:
# [('the', 127),
#  ('of', 63),
#  ('and', 52),
#  ('to', 42),
#  ('a', 40),
#  ('city', 32),
#  ('digital', 23),
#  ('is', 22),
#  ('that', 22),
#  ('barcelona', 20),
#  ('in', 15),
#  ('for', 15),
#  ('this', 13),
#  ('systems', 12),
#  ('are', 12)]

# %% [markdown]
# las 15 palabras con mas frecuencia

# %%
palabras = [tupla[0] for tupla in top_15_palabras]
frecuencias = [tupla[1] for tupla in top_15_palabras]

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(palabras, frecuencias, color='skyblue')
plt.xlabel('Frecuencia')
plt.ylabel('Palabra')
plt.title('Frecuencia de Palabras')
plt.gca().invert_yaxis()
plt.savefig('frecuencia_palabras.png')
plt.show()

# %% [markdown]
# Podemos ver en este grafico que las palabras con mas frecuencia son las que sirven de enlaces entre palabras o llamadas stopword, pero estas palabras no me aportan informacion relevante para mi estudio. solo digital, barcelona y systems. me sirven para mi estudio.

# %% [markdown]
# ##### Ejercicio 2
# Saca las stopwords y realiza stemming en tu conjunto de datos.
#
# ##### Stopwords:
# La eliminación de palabras irrelevantes es un paso crucial de preprocesamiento de texto en el análisis de sentimientos que implica eliminar palabras comunes e irrelevantes que probablemente no transmitan mucho sentimiento. Las palabras vacías son palabras que son muy comunes en un idioma y no tienen mucho significado, como "y", "el", "de" y "ello". Estas palabras pueden causar ruido y sesgar el análisis si no se eliminan.

# %%
stop_words = set(stopwords.words('english'))
tokens_filtrados2 = [word for word in tokens_filtrados if word not in stop_words]
print(tokens_filtrados2)
# Out:
# ['barcelona', 'shapes', 'future', 'city', 'planning', 'city', 'barcelona', 'cooking', 'something', 'truly', 'special', 'local', 'digital', 'twin', 'ltd', 'resembles', 'delicious', 'lasagna', 'like', 'dish', 'layers', 'pasta', 'cheese', 'sauce', 'digital', 'twin', 'aims', 'include', 'different', 'layers', 'systems', 'create', 'virtual', 'replica', 'city', 'much', 'like', 'first', 'step', 'including', 'solid', 'base', 'cooking', 'lasagna', 'barcelona', 'replaced', 'pasta', 'virtual', 'representation', 'city', 'physical', 'reality', 'bottom', 'layer', 'made', 'map', 'images', 'city', 'satellite', 'photographs', 'street', 'furniture', 'trees', 'buildings', 'people', 'represents', 'physical', 'world', 'explains', 'jordi', 'cirera', 'director', 'knowledge', 'society', 'office', 'barcelona', 'city', 'council', 'enough', 'truly', 'grasp', 'city', 'works', 'need', 'throw', 'ingredients', 'mix', 'city', 'council', 'barcelona', 'collaboration', 'barcelona', 'supercomputing', 'centre', 'barcelona', 'regional', 'agency', 'started', 'new', 'much', 'ambitious', 'project', 'aim', 'add', 'new', 'layers', 'lasagna', 'namely', 'different', 'systems', 'affect', 'functioning', 'behaviour', 'cities', 'air', 'pollution', 'noise', 'monitoring', 'goods', 'distributed', 'throughout', 'city', 'traffic', 'management', 'monitoring', 'people', 'move', 'around', 'systems', 'compose', 'city', 'model', 'notes', 'cirera', 'want', 'incorporate', 'systems', 'laws', 'govern', 'digital', 'comprehensive', 'view', 'barcelona', 'local', 'digital', 'twin', 'would', 'allow', 'decision', 'makers', 'run', 'simulations', 'predict', 'changes', 'one', 'system', 'affect', 'city', 'according', 'cirera', 'technology', 'allow', 'city', 'council', 'design', 'orient', 'prepare', 'barcelona', 'digital', 'twins', 'urban', 'planning', 'revolution', 'digital', 'twins', 'much', 'digital', 'replica', 'physical', 'systems', 'people', 'environments', 'different', 'data', 'analysis', 'visualisation', 'approaches', 'integrate', 'data', 'various', 'sources', 'real', 'time', 'assess', 'future', 'scenarios', 'advanced', 'simulations', 'applied', 'urban', 'contexts', 'dts', 'revolutionise', 'cities', 'approach', 'management', 'monitoring', 'future', 'planning', 'digital', 'twins', 'proven', 'many', 'practical', 'applications', 'cities', 'rotterdam', 'instance', 'building', 'city', 'operations', 'platform', 'allows', 'disclosure', 'visualisation', 'energy', 'usage', 'data', 'individual', 'buildings', 'entire', 'area', 'flanders', 'part', 'duet', 'digital', 'twins', 'project', 'developing', 'traffic', 'model', 'estimates', 'expected', 'traffic', 'volume', 'surrounding', 'streets', 'one', 'streets', 'closed', 'interaction', 'traffic', 'model', 'air', 'quality', 'model', 'allows', 'simulation', 'impact', 'traffic', 'measures', 'mobility', 'environment', 'city', 'utrecht', 'also', 'using', 'local', 'digital', 'twin', 'developing', 'solution', 'adapted', 'various', 'domains', 'mobility', 'healthy', 'urban', 'living', 'shaping', 'city', 'proximity', 'barcelona', 'developed', 'digital', 'twin', 'platform', 'serves', 'proof', 'concept', 'starting', 'point', 'city', 'ambitious', 'urban', 'planning', 'project', 'platform', 'provides', 'tool', 'assess', 'whether', 'city', 'complies', 'provision', 'services', 'facilities', 'city', 'proximity', 'concept', 'based', 'model', 'term', 'coined', 'researcher', 'carlos', 'moreno', 'based', 'idea', 'essential', 'human', 'needs', 'within', 'reach', 'foot', 'bike', 'means', 'housing', 'work', 'food', 'health', 'education', 'culture', 'leisure', 'easily', 'accessible', 'everyone', 'barcelona', 'platform', 'analyses', 'accessibility', 'public', 'facilities', 'metro', 'stations', 'hospitals', 'libraries', 'water', 'fountains', 'among', 'many', 'others', 'platform', 'addresses', 'six', 'social', 'functions', 'model', 'could', 'include', 'data', 'set', 'city', 'council', 'available', 'says', 'cirera', 'digital', 'twin', 'allows', 'policy', 'makers', 'evaluate', 'impact',  ...

# %% [markdown]
# Eliminamos las stopword, nos permite obtener solo las palabras relevantes de mi texto y que me dan informacion.

# %%
frecuencia_palabras2 = Counter(tokens_filtrados2) #(contabiliza, cuantas veces se repite cada "palabra" de caracteres alfabeticos sin incluir las stopwords.)
print(frecuencia_palabras2)
# Out:
# Counter({'city': 32, 'digital': 23, 'barcelona': 20, 'systems': 12, 'cities': 11, 'twin': 10, 'model': 10, 'twins': 9, 'platform': 9, 'different': 8, 'project': 8, 'data': 7, 'planning': 6, 'local': 6, 'cirera': 6, 'council': 6, 'new': 6, 'traffic': 6, 'many': 6, 'lasagna': 5, 'urban': 5, 'phase': 5, 'future': 4, 'layers': 4, 'aims': 4, 'physical': 4, 'people': 4, 'knowledge': 4, 'collaboration': 4, 'supercomputing': 4, 'ambitious': 4, 'affect': 4, 'time': 4, 'assess': 4, 'impact': 4, 'set': 4, 'use': 4, 'european': 4, 'something': 3, 'like': 3, 'include': 3, 'much': 3, 'first': 3, 'aim': 3, 'air': 3, 'monitoring': 3, 'govern': 3, 'would': 3, 'one': 3, 'technology': 3, 'allows': 3, 'developing': 3, 'concept': 3, 'facilities': 3, 'culture': 3, 'social': 3, 'projects': 3, 'example': 3, 'ortuño': 3, 'potential': 3, 'complex': 3, 'levels': 3, 'able': 3, 'bologna': 3, 'possible': 3, 'eu': 3, 'ldts': 3, 'cooking': 2, 'truly': 2, 'dish': 2, 'pasta': 2, 'virtual': 2, 'replica': 2, 'including': 2, 'map': 2, 'street': 2, 'buildings': 2, 'jordi': 2, 'society': 2, 'office': 2, 'ingredients': 2, 'centre': 2, 'regional': 2, 'add': 2, 'pollution': 2, 'noise': 2, 'management': 2, 'around': 2, 'incorporate': 2, 'laws': 2, 'allow': 2, 'makers': 2, 'simulations': 2, 'changes': 2, 'system': 2, 'visualisation': 2, 'various': 2, 'instance': 2, 'building': 2, 'streets': 2, 'measures': 2, 'mobility': 2, 'also': 2, 'proximity': 2, 'developed': 2, 'serves': 2, 'based': 2, 'idea': 2, 'essential': 2, 'needs': 2, 'within': 2, 'accessibility': 2, 'public': 2, 'stations': 2, 'among': 2, 'could': 2, 'available': 2, 'identify': 2, 'areas': 2, 'innovation': 2, 'community': 2, 'modelling': 2, 'programme': 2, 'adding': 2, 'worked': 2, 'change': 2, 'completed': 2, 'rules': 2, 'provide': 2, 'understanding': 2, 'significant': 2, 'together': 2, 'center': 2, 'cineca': 2, 'consortium': 2, 'universities': 2, 'development': 2, 'long': 2, 'tools': 2, 'ldt': 2, 'achieving': 2, 'communities': 2, 'best': 2, 'practices': 2, 'shapes': 1, 'special': 1, 'ltd': 1, 'resembles': 1, 'delicious': 1, 'cheese': 1, 'sauce': 1, 'create': 1, 'step': 1, 'solid': 1, 'base': 1, 'replaced': 1, 'representation': 1, 'reality': 1, 'bottom': 1, 'layer': 1, 'made': 1, 'images': 1, 'satellite': 1, 'photographs': 1, 'furniture': 1, 'trees': 1, 'represents': 1, 'world': 1, 'explains': 1, 'director': 1, 'enough': 1, 'grasp': 1, 'works': 1, 'need': 1, 'throw': 1, 'mix': 1, 'agency': 1, 'started': 1, 'namely': 1, 'functioning': 1, 'behaviour': 1, 'goods': 1, 'distributed': 1, 'throughout': 1, 'move': 1, 'compose': 1, 'notes': 1, 'want': 1, 'comprehensive': 1, 'view': 1, 'decision': 1, 'run': 1, 'predict': 1, 'according': 1, 'design': 1, 'orient': 1, 'prepare': 1, 'revolution': 1, 'environments': 1, 'analysis': 1, 'approaches': 1, 'integrate': 1, 'sources': 1, 'real': 1, 'scenarios': 1, 'advanced': 1, 'applied': 1, 'contexts': 1, 'dts': 1, 'revolutionise': 1, 'approach': 1, 'proven': 1, 'practical': 1, 'applications': 1, 'rotterdam': 1, 'operations': 1, 'disclosure': 1, 'energy': 1, 'usage': 1, 'individual': 1, 'entire': 1, 'area': 1, 'flanders': 1, 'part': 1, 'duet': 1, 'estimates': 1, 'expected': 1, 'volume': 1, 'surrounding': 1, 'closed': 1, 'interaction': 1, 'quality': 1, 'simulation': 1, 'environment': 1, 'utrecht': 1, 'using': 1, 'solution': 1, 'adapted': 1, 'domains': 1, 'healthy': 1, 'living': 1, 'shaping': 1, 'proof': 1, 'starting': 1, 'point': 1, 'provides': 1, 'tool': 1, 'whether': 1, 'complies': 1, 'provision': 1, 'services': 1, 'term': 1, 'coined': 1, 'researcher': 1, 'carlos': 1, 'moreno': 1, 'human': 1, 'reach': 1, 'foot': 1, 'bike': 1, 'means': 1, 'housing': 1, 'work': 1, 'food': 1, 'health': 1, 'education': 1, 'leisure': 1, 'easily': 1, 'accessible': 1, 'everyone': 1, 'analyses': 1, 'metro': 1, 'hospitals': 1, 'libraries': 1, 'water': 1, 'fountains': 1, 'others': 1, 'addresses': 1, 'six': 1, 'functions': 1, 'says': 1, 'policy': 1, 'evaluate': 1, 'construction': 1, 'infrastructure': 1, ' ...

# %%
top2_15_palabras = frecuencia_palabras2.most_common(15)
top2_15_palabras
# Out:
# [('city', 32),
#  ('digital', 23),
#  ('barcelona', 20),
#  ('systems', 12),
#  ('cities', 11),
#  ('twin', 10),
#  ('model', 10),
#  ('twins', 9),
#  ('platform', 9),
#  ('different', 8),
#  ('project', 8),
#  ('data', 7),
#  ('planning', 6),
#  ('local', 6),
#  ('cirera', 6)]

# %% [markdown]
# Las 15 palabras con mas frecuencia sin stopwords. quiero mostrar solo las primeras 15

# %%
palabras = [tupla[0] for tupla in top2_15_palabras]
frecuencias = [tupla[1] for tupla in top2_15_palabras]

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(palabras, frecuencias, color='skyblue')
plt.xlabel('Frecuencia')
plt.ylabel('Palabra')
plt.title('Frecuencia de Palabras sin stopwords')
plt.gca().invert_yaxis()
plt.savefig('frecuencia_palabras sin stopwords.png')
plt.show()

# %% [markdown]
# Ahora tenemos la frecuencia de palabras sin stopword, que son palabras que si tiene un significado o son importantes de estudiar para mi conjunto de datos que habla sobre barcelona y el desarrollo de una replica digital para gestionar eficientemente la ciudad.

# %% [markdown]
# ##### Stemmer:
# Un stemmer es una herramienta utilizada en el procesamiento del lenguaje natural (NLP) que se utiliza para reducir las palabras a su raíz o forma base, conocida como "stem". Esto se hace eliminando los afijos de las palabras, como los sufijos y prefijos, para producir la forma base de una palabra.
#
# El objetivo principal del stemming es reducir las palabras a su forma más básica, lo que ayuda a normalizar el texto y reducir la dimensionalidad en tareas de análisis de texto, como la recuperación de información, la clasificación de texto y el análisis de sentimientos.

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in tokens_filtrados2]
print(stemmed_words)
# Out:
# ['barcelona', 'shape', 'futur', 'citi', 'plan', 'citi', 'barcelona', 'cook', 'someth', 'truli', 'special', 'local', 'digit', 'twin', 'ltd', 'resembl', 'delici', 'lasagna', 'like', 'dish', 'layer', 'pasta', 'chees', 'sauc', 'digit', 'twin', 'aim', 'includ', 'differ', 'layer', 'system', 'creat', 'virtual', 'replica', 'citi', 'much', 'like', 'first', 'step', 'includ', 'solid', 'base', 'cook', 'lasagna', 'barcelona', 'replac', 'pasta', 'virtual', 'represent', 'citi', 'physic', 'realiti', 'bottom', 'layer', 'made', 'map', 'imag', 'citi', 'satellit', 'photograph', 'street', 'furnitur', 'tree', 'build', 'peopl', 'repres', 'physic', 'world', 'explain', 'jordi', 'cirera', 'director', 'knowledg', 'societi', 'offic', 'barcelona', 'citi', 'council', 'enough', 'truli', 'grasp', 'citi', 'work', 'need', 'throw', 'ingredi', 'mix', 'citi', 'council', 'barcelona', 'collabor', 'barcelona', 'supercomput', 'centr', 'barcelona', 'region', 'agenc', 'start', 'new', 'much', 'ambiti', 'project', 'aim', 'add', 'new', 'layer', 'lasagna', 'name', 'differ', 'system', 'affect', 'function', 'behaviour', 'citi', 'air', 'pollut', 'nois', 'monitor', 'good', 'distribut', 'throughout', 'citi', 'traffic', 'manag', 'monitor', 'peopl', 'move', 'around', 'system', 'compos', 'citi', 'model', 'note', 'cirera', 'want', 'incorpor', 'system', 'law', 'govern', 'digit', 'comprehens', 'view', 'barcelona', 'local', 'digit', 'twin', 'would', 'allow', 'decis', 'maker', 'run', 'simul', 'predict', 'chang', 'one', 'system', 'affect', 'citi', 'accord', 'cirera', 'technolog', 'allow', 'citi', 'council', 'design', 'orient', 'prepar', 'barcelona', 'digit', 'twin', 'urban', 'plan', 'revolut', 'digit', 'twin', 'much', 'digit', 'replica', 'physic', 'system', 'peopl', 'environ', 'differ', 'data', 'analysi', 'visualis', 'approach', 'integr', 'data', 'variou', 'sourc', 'real', 'time', 'assess', 'futur', 'scenario', 'advanc', 'simul', 'appli', 'urban', 'context', 'dt', 'revolutionis', 'citi', 'approach', 'manag', 'monitor', 'futur', 'plan', 'digit', 'twin', 'proven', 'mani', 'practic', 'applic', 'citi', 'rotterdam', 'instanc', 'build', 'citi', 'oper', 'platform', 'allow', 'disclosur', 'visualis', 'energi', 'usag', 'data', 'individu', 'build', 'entir', 'area', 'flander', 'part', 'duet', 'digit', 'twin', 'project', 'develop', 'traffic', 'model', 'estim', 'expect', 'traffic', 'volum', 'surround', 'street', 'one', 'street', 'close', 'interact', 'traffic', 'model', 'air', 'qualiti', 'model', 'allow', 'simul', 'impact', 'traffic', 'measur', 'mobil', 'environ', 'citi', 'utrecht', 'also', 'use', 'local', 'digit', 'twin', 'develop', 'solut', 'adapt', 'variou', 'domain', 'mobil', 'healthi', 'urban', 'live', 'shape', 'citi', 'proxim', 'barcelona', 'develop', 'digit', 'twin', 'platform', 'serv', 'proof', 'concept', 'start', 'point', 'citi', 'ambiti', 'urban', 'plan', 'project', 'platform', 'provid', 'tool', 'assess', 'whether', 'citi', 'compli', 'provis', 'servic', 'facil', 'citi', 'proxim', 'concept', 'base', 'model', 'term', 'coin', 'research', 'carlo', 'moreno', 'base', 'idea', 'essenti', 'human', 'need', 'within', 'reach', 'foot', 'bike', 'mean', 'hous', 'work', 'food', 'health', 'educ', 'cultur', 'leisur', 'easili', 'access', 'everyon', 'barcelona', 'platform', 'analys', 'access', 'public', 'facil', 'metro', 'station', 'hospit', 'librari', 'water', 'fountain', 'among', 'mani', 'other', 'platform', 'address', 'six', 'social', 'function', 'model', 'could', 'includ', 'data', 'set', 'citi', 'council', 'avail', 'say', 'cirera', 'digit', 'twin', 'allow', 'polici', 'maker', 'evalu', 'impact', 'new', 'construct', 'project', 'citi', 'infrastructur', 'assess', 'access', 'facil', 'public', 'includ', 'data', 'municip', 'regist', 'exampl', 'could', 'identifi', 'area', 'cover', 'model', 'also', 'mani', 'peopl', 'left', 'remark', 'platform', 'replic', 'citi', 'urban', 'plan', 'need', 'adapt', 'citi', 'region', 'complic', 'acknowledg', 'jordi', 'ortuño', 'innov', 'manag', 'knowledg', 'societi', 'offic', 'barcelona ...

# %%
frecuencia_palabras3 = Counter(stemmed_words)
print(frecuencia_palabras3)
# Out:
# Counter({'citi': 43, 'digit': 23, 'barcelona': 20, 'twin': 19, 'system': 14, 'model': 12, 'project': 11, 'platform': 9, 'aim': 8, 'differ': 8, 'develop': 8, 'council': 7, 'data': 7, 'plan': 6, 'local': 6, 'includ': 6, 'cirera': 6, 'new': 6, 'traffic': 6, 'mani': 6, 'use': 6, 'lasagna': 5, 'layer': 5, 'work': 5, 'collabor': 5, 'supercomput': 5, 'allow': 5, 'chang': 5, 'urban': 5, 'phase': 5, 'ldt': 5, 'futur': 4, 'physic': 4, 'street': 4, 'build': 4, 'peopl': 4, 'knowledg': 4, 'ambiti': 4, 'affect': 4, 'monitor': 4, 'time': 4, 'assess': 4, 'impact': 4, 'set': 4, 'commun': 4, 'complex': 4, 'level': 4, 'european': 4, 'someth': 3, 'like': 3, 'creat': 3, 'much': 3, 'first': 3, 'base': 3, 'need': 3, 'centr': 3, 'region': 3, 'air': 3, 'manag': 3, 'incorpor': 3, 'govern': 3, 'would': 3, 'simul': 3, 'one': 3, 'technolog': 3, 'practic': 3, 'area': 3, 'close': 3, 'concept': 3, 'provid': 3, 'tool': 3, 'facil': 3, 'cultur': 3, 'access': 3, 'social': 3, 'exampl': 3, 'ortuño': 3, 'innov': 3, 'potenti': 3, 'complet': 3, 'abl': 3, 'bologna': 3, 'univers': 3, 'share': 3, 'happen': 3, 'possibl': 3, 'eu': 3, 'shape': 2, 'cook': 2, 'truli': 2, 'dish': 2, 'pasta': 2, 'virtual': 2, 'replica': 2, 'map': 2, 'photograph': 2, 'repres': 2, 'jordi': 2, 'societi': 2, 'offic': 2, 'ingredi': 2, 'start': 2, 'add': 2, 'function': 2, 'pollut': 2, 'nois': 2, 'move': 2, 'around': 2, 'law': 2, 'decis': 2, 'maker': 2, 'environ': 2, 'visualis': 2, 'approach': 2, 'variou': 2, 'instanc': 2, 'interact': 2, 'measur': 2, 'mobil': 2, 'also': 2, 'adapt': 2, 'proxim': 2, 'serv': 2, 'point': 2, 'research': 2, 'idea': 2, 'essenti': 2, 'within': 2, 'public': 2, 'station': 2, 'among': 2, 'could': 2, 'avail': 2, 'municip': 2, 'identifi': 2, 'programm': 2, 'becom': 2, 'ad': 2, 'result': 2, 'launch': 2, 'rule': 2, 'understand': 2, 'enabl': 2, 'signific': 2, 'togeth': 2, 'center': 2, 'cineca': 2, 'consortium': 2, 'defin': 2, 'initi': 2, 'goal': 2, 'long': 2, 'achiev': 2, 'ensur': 2, 'best': 2, 'specif': 2, 'special': 1, 'ltd': 1, 'resembl': 1, 'delici': 1, 'chees': 1, 'sauc': 1, 'step': 1, 'solid': 1, 'replac': 1, 'represent': 1, 'realiti': 1, 'bottom': 1, 'made': 1, 'imag': 1, 'satellit': 1, 'furnitur': 1, 'tree': 1, 'world': 1, 'explain': 1, 'director': 1, 'enough': 1, 'grasp': 1, 'throw': 1, 'mix': 1, 'agenc': 1, 'name': 1, 'behaviour': 1, 'good': 1, 'distribut': 1, 'throughout': 1, 'compos': 1, 'note': 1, 'want': 1, 'comprehens': 1, 'view': 1, 'run': 1, 'predict': 1, 'accord': 1, 'design': 1, 'orient': 1, 'prepar': 1, 'revolut': 1, 'analysi': 1, 'integr': 1, 'sourc': 1, 'real': 1, 'scenario': 1, 'advanc': 1, 'appli': 1, 'context': 1, 'dt': 1, 'revolutionis': 1, 'proven': 1, 'applic': 1, 'rotterdam': 1, 'oper': 1, 'disclosur': 1, 'energi': 1, 'usag': 1, 'individu': 1, 'entir': 1, 'flander': 1, 'part': 1, 'duet': 1, 'estim': 1, 'expect': 1, 'volum': 1, 'surround': 1, 'qualiti': 1, 'utrecht': 1, 'solut': 1, 'domain': 1, 'healthi': 1, 'live': 1, 'proof': 1, 'whether': 1, 'compli': 1, 'provis': 1, 'servic': 1, 'term': 1, 'coin': 1, 'carlo': 1, 'moreno': 1, 'human': 1, 'reach': 1, 'foot': 1, 'bike': 1, 'mean': 1, 'hous': 1, 'food': 1, 'health': 1, 'educ': 1, 'leisur': 1, 'easili': 1, 'everyon': 1, 'analys': 1, 'metro': 1, 'hospit': 1, 'librari': 1, 'water': 1, 'fountain': 1, 'other': 1, 'address': 1, 'six': 1, 'say': 1, 'polici': 1, 'evalu': 1, 'construct': 1, 'infrastructur': 1, 'regist': 1, 'cover': 1, 'left': 1, 'remark': 1, 'replic': 1, 'complic': 1, 'acknowledg': 1, 'matter': 1, 'along': 1, 'depend': 1, 'intend': 1, 'locat': 1, 'electr': 1, 'car': 1, 'charg': 1, 'bicycl': 1, 'rack': 1, 'even': 1, 'next': 1, 'interven': 1, 'known': 1, 'copi': 1, 'highli': 1, 'detail': 1, 'static': 1, 'mention': 1, 'second': 1, 'stage': 1, 'reproduc': 1, 'introduc': 1, 'small': 1, 'choic': 1, 'sugar': 1, 'instead': 1, 'salt': 1, 'quit': 1, 'true': 1, 'citizen': 1, 'employ': 1, 'pattern': 1, 'therefor': 1, 'neighbour': 1, 'planner': 1, 'deeper': 1, 'make': 1, 'inform': 1, 'posit': 1, 'howev': 1, 'r ...

# %%
top3_15_palabras = frecuencia_palabras3.most_common(15)
top3_15_palabras
# Out:
# [('citi', 43),
#  ('digit', 23),
#  ('barcelona', 20),
#  ('twin', 19),
#  ('system', 14),
#  ('model', 12),
#  ('project', 11),
#  ('platform', 9),
#  ('aim', 8),
#  ('differ', 8),
#  ('develop', 8),
#  ('council', 7),
#  ('data', 7),
#  ('plan', 6),
#  ('local', 6)]

# %%
palabras = [tupla[0] for tupla in top3_15_palabras]
frecuencias = [tupla[1] for tupla in top3_15_palabras]

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(palabras, frecuencias, color='skyblue')
plt.xlabel('Frecuencia')
plt.ylabel('Palabra')
plt.title('Frecuencia de Palabras sin stop words y con stemmer')
plt.gca().invert_yaxis() 
plt.savefig('Frecuencia de Palabras sin stop words y con stemmer.png')
plt.show()

# %%
archivos_imagenes = ['frecuencia_palabras.png', 'frecuencia_palabras sin stopwords.png', 'Frecuencia de Palabras sin stop words y con stemmer.png']

for archivo in archivos_imagenes:
    imagen = mpimg.imread(archivo)
    plt.figure(figsize=(15, 10))
    plt.imshow(imagen)
    plt.axis('off')
    plt.show()

# %% [markdown]
# Obersevamos que al quitar las stopwords y hacer el stemming, las palabras aumentaron su frecuencia, para mi conjunto de datos la palabra city tuvo la mayor frecuencia  42, digit: 23, barcelona: 20. tambien puedo resaltar que las palabras que contienen nombres, siempre van a mantener su frecuencia, mientras que las palabras que pueden tener derivaciones, varian al aplicar el stemming.

# %% [markdown]
# ##### Ejercicio 3
# Realiza sentimiento analysis en tu conjunto de datos.

# %%
sentimiento_text = ' '.join(stemmed_words)
sentimiento = SentimentIntensityAnalyzer().polarity_scores(sentimiento_text)
print(sentimiento)


compound_score = sentimiento['compound']

if compound_score >= 0.05:
    sentimiento = "Positiu"
elif compound_score <= -0.05:
    sentimiento = "Negatiu"
else:
    sentiment = "Neutre"

print(f'\nPuntuació de sentiment: {compound_score}')
print(f'Classificació de sentiment: {sentimiento}')
# Out:
# {'neg': 0.007, 'neu': 0.913, 'pos': 0.079, 'compound': 0.9947}
#
# Puntuació de sentiment: 0.9947
# Classificació de sentiment: Positiu

# %%
sentimiento = {'neg': 0.007, 'neu': 0.913, 'pos': 0.079, 'compound': 0.9947}

etiquetas = ['Negativo', 'Neutral', 'Positivo']
valores = [sentimiento['neg'], sentimiento['neu'], sentimiento['pos']]

plt.figure(figsize=(8, 6))
plt.bar(etiquetas, valores, color=['red', 'gray', 'green'])

plt.title('Evaluación de Sentimiento del Texto')
plt.xlabel('Sentimiento')
plt.ylabel('Porcentaje')

plt.show()

# %% [markdown]
# El analizador de sentimientos VADER incluido en NLTK para calcular la polaridad del sentimiento del texto. La polaridad se encuentra en el rango de -1 a 1, donde valores más cercanos a 1 indican un sentimiento más positivo, valores más cercanos a -1 indican un sentimiento más negativo, y valores cercanos a 0 indican neutralidad.
#
# neg: 0.007 significa que el 0.7% de las palabras en el texto fueron evaluadas como negativas.
# neu: 0.913 significa que el 91.3% de las palabras en el texto fueron evaluadas como neutras.
# pos: 0.079 significa que el 7.9% de las palabras en el texto fueron evaluadas como positivas.
# compound: 0.9947 es la puntuación compuesta, que es una medida agregada del sentimiento general del texto. En este caso, 0.9947 indica un sentimiento muy positivo.
# Dado que la puntuación compound es cercana a 1, y la puntuación positiva es considerablemente mayor que la negativa, podemos inferir que el texto tiene un tono positivo. Específicamente, el 7.9% de las palabras fueron evaluadas como positivas, y la evaluación general del sentimiento del texto (compuesta) es muy positiva. Por lo tanto, puedes concluir que tu texto es positivo en términos de su tono emocional general.
